# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import gym

# %%
from JSAnimation.IPython_display import display_animation
from matplotlib import animation
from IPython.display import display

def display_frames_as_gif(frames):
    '''Displays a list of frames as a gif, with controls'''
    plt.figure(figsize=(frames[0].shape[1]/72.0, frames[0].shape[0]/72.0), dpi=72)
    patch = plt.imshow(frames[0])
    plt.axis('off')
    
    def animate(i):
        patch.set_data(frames[i])
        
    anim = animation.FuncAnimation(plt.gcf(), animate, frames=len(frames), interval=50)
    
    anim.save('movie_cartpole_DQN.mp4')
    display(display_animation(anim, default_mode='loop'))

# %%
# using namedtuple
from collections import namedtuple

# ex
# Tr = namedtuple('tr', ('name_a', 'value_b'))
# Tr_object = Tr('nameA', 100)

# print(Tr_object)
# print(Tr_object.value_b)

Transition = namedtuple('Transition', ('state', 'action', 'next_state', 'reward'))

# %%
ENV = 'CartPole-v0'
GAMMA = 0.99 # 시간할인율
MAX_STEPS = 200 # 1에피소드 당 최대 단계 수
NUM_EPISODES = 500 # 최대 에피소드 수

# %%
# experience replay
class ReplayMemory:
    def __init__(self, CAPACITY):
        self.capacity = CAPACITY
        self.memory = []
        self.index = 0
        
    def push(self, state, action, state_next, reward):
        '''transition = (state, action, state_next, reward)을 메모리에 저장'''
        if len(self.memory) < self.capacity:
            self.memory.append(None)
            
        self.memory[self.index] = Transition(state, action, state_next, reward)
        self.index = (self.index + 1) % self.capacity
        
    def sample(self, batch_size):
        '''batch_size 개수만큼 무작위로 저장된 transition을 추출'''
        return random.sample(self.memory, batch_size)
    
    def __len__(self):
        '''len 함수로 현재 저장된 transition 개수를 반환'''
        return len(self.memory)

# %%
# NN
import torch.nn as nn
import torch.nn.functional as F

class Net(nn.Module):
    def __init__(self, n_in, n_mid, n_out):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(n_in, n_mid)
        self.fc2 = nn.Linear(n_mid, n_mid)
        self.fc3 = nn.Linear(n_mid, n_out)
        
    def forward(self, x):
        h1 = F.relu(self.fc1(x))
        h2 = F.relu(self.fc2(h1))
        output = self.fc3(h2)
        return output

# %%
import random
import torch
from torch import nn
from torch import optim
import torch.nn.functional as F

BATCH_SIZE = 32
CAPACITY = 10000

class Brain:
    def __init__(self, num_states, num_actions):
        self.num_actions = num_actions # 행동 가짓수(2)
        
        # transition을 기억하기 위한 메모리 객체 생성
        self.memory = ReplayMemory(CAPACITY)
        
        # nn
        n_in, n_mid, n_out = num_states, 32, num_actions
        self.main_q_network = Net(n_in, n_mid, n_out)
        self.target_q_network = Net(n_in, n_mid, n_out)
        print(self.main_q_network)
        
        self.optimizer = optim.Adam(self.main_q_network.parameters(), lr=0.0001)
        
    def replay(self):
        '''Experience Replay로 신경망의 결합 가중치 학습'''

        # 1. 저장된 transition의 수를 확인
        if len(self.memory)  < BATCH_SIZE:
            return
        
        # 2. 미니배치 생성
        self.batch, self.state_batch, self.action_batch, self.reward_batch, self.non_final_next_states = self.make_minibatch()
        
        # 3. 정답신호로 사용할 Q(s_t, a_t)를 계산
        self.expected_state_action_values = self.get_expected_state_action_values()
        
        # 4. 결합 가중치 수정
        self.update_main_q_network()

    def decide_action(self, state, episode):
        '''현재 상태에 따라 행동을 결정한다'''
        # ε-greedy 알고리즘에서 서서히 최적행동의 비중을 늘린다
        epsilon = 0.5 * (1 / (episode + 1))

        if epsilon <= np.random.uniform(0, 1):
            self.main_q_network.eval()  # 신경망을 추론 모드로 전환
            with torch.no_grad():
                action = self.main_q_network(state).max(1)[1].view(1, 1)
            # 신경망 출력의 최댓값에 대한 인덱스 = max(1)[1]
            # .view(1,1)은 [torch.LongTensor of size 1] 을 size 1*1로 변환하는 역할을 한다

        else:
            # 행동을 무작위로 반환(0 혹은 1)
            action = torch.LongTensor(
                [[random.randrange(self.num_actions)]])  # 행동을 무작위로 반환(0 혹은 1)
            # action은 [torch.LongTensor of size 1*1] 형태가 된다

        return action
    
    def make_minibatch(self):
        # 메모리 객체에서 미니배치 추출
        transitions = self.memory.sample(BATCH_SIZE)
        
        batch = Transition(*zip(*transitions))
        
        state_batch = torch.cat(batch.state)
        action_batch = torch.cat(batch.action)
        reward_batch = torch.cat(batch.reward)
        non_final_next_states = torch.cat([s for s in batch.next_state if s is not None])
        
        return batch, state_batch, action_batch, reward_batch, non_final_next_states
    
    def get_expected_state_action_values(self):
        self.main_q_network.eval()
        self. target_q_network.eval()
        
        # 신경망으로 Q(s_t,a_t)를 계산
        # self.model(state_batch)은 왼쪽, 오른쪽에 대한 Q값을 출력하며 [torch.FloatTensor of size BATCH_SIZEx2] 형태
        # 여기서부터 실행한 행동 a_t에 대한 Q값을 계산하므로 action_batch에서 취한 행동 a_t가 왼쪽이냐 오른쪽이냐에 대한 인덱스를 구하고,
        # 이에 대한 Q값을 gather 메서드로 모아온다
        self.state_action_values = self.main_q_network(self.state_batch).gather(1, self.action_batch)
        
        non_final_mask = torch.ByteTensor(tuple(map(lambda s: s is not None, self.batch.next_state)))
        
        next_state_values = torch.zeros(BATCH_SIZE)
        a_m = torch.zeros(BATCH_SIZE).type(torch.LongTensor)
        
        a_m[non_final_mask] = self.main_q_network(self.non_final_next_states).detach().max(1)[1]
        
        a_m_non_final_states = a_m[non_final_mask].view(-1, 1)
        
        next_state_values[non_final_mask] = self.target_q_network(self.non_final_next_states).gather(1, a_m_non_final_states).detach().squeeze()
        
        expected_state_action_values = self.reward_batch + GAMMA * next_state_values
        
        return expected_state_action_values
    
    
    def update_main_q_network(self):
        self.main_q_network.train()
        
        # smooth_l1_loss : Huber function
        loss = F.smooth_l1_loss(self.state_action_values, self.expected_state_action_values.unsqueeze(1))
        
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()
        
    def update_target_q_network(self):
        '''Target Q-Network을 Main Q-Network와 맞춤'''
        self.target_q_network.load_state_dict(self.main_q_network.state_dict())

# %%
class Agent:
    def __init__(self, num_states, num_actions):
        self.brain = Brain(num_states, num_actions)
        
    def update_q_function(self):
        self.brain.replay()
    
    def get_action(self, state, episode):
        action = self.brain.decide_action(state, episode)
        return action

    def memorize(self, state, action, state_next, reward):
        self.brain.memory.push(state, action, state_next, reward)
        
    def update_target_q_function(self):
        self.brain.update_target_q_network()

# %%
class Environment:
    def __init__(self):
        self.env = gym.make(ENV)
        num_states = self.env.observation_space.shape[0]
        num_actions = self.env.action_space.n
        self.agent = Agent(num_states, num_actions)
        
    def run(self):
        episode_10_list = np.zeros(10)
        complete_episodes = 0
        episode_final = False
        frames = []
        
        for episode in range(NUM_EPISODES):
            observation = self.env.reset()
            
            state = observation
            state = torch.from_numpy(state).type(torch.FloatTensor)
            state = torch.unsqueeze(state, 0)
            
            for step in range(MAX_STEPS):
#                 if episode_final is True:
#                     frames.append(self.env.render(mode='rgb_array'))
                action = self.agent.get_action(state, episode)
                
                observation_next, _, done, _ = self.env.step(action.item())
                
                if done:
                    state_next = None
                    episode_10_list = np.hstack((episode_10_list[1:], step + 1))
                    
                    if step < 195:
                        reward = torch.FloatTensor([-1.0])
                        complete_episodes = 0
                    else:
                        reward = torch.FloatTensor([1.0])
                        complete_episodes = complete_episodes + 1
                        
                else:
                    reward = torch.FloatTensor([0.0])
                    state_next = observation_next
                    state_next = torch.from_numpy(state_next).type(torch.FloatTensor)
                    state_next = torch.unsqueeze(state_next, 0)
                    
                self.agent.memorize(state, action, state_next, reward)
                
                self.agent.update_q_function()
                
                state = state_next
                
                if done:
                    print('%d Episode : Finished after %d steps : Current avg of 10 episode\'s step = %.1lf' % (episode, step + 1, episode_10_list.mean()))
                    if (episode % 2 == 0):
                        self.agent.update_target_q_function()
                    break
                
                if episode_final is True:
#                     display_frames_as_gif(frames)
                    break
                
                if complete_episodes >= 10:
                    print("10 episode success")
                    episode_final = True

# %%
cartpole_env = Environment()
cartpole_env.run()
# Out:
# Net(
#   (fc1): Linear(in_features=4, out_features=32, bias=True)
#   (fc2): Linear(in_features=32, out_features=32, bias=True)
#   (fc3): Linear(in_features=32, out_features=2, bias=True)
# )
# 0 Episode : Finished after 9 steps : Current avg of 10 episode's step = 0.9
# 1 Episode : Finished after 12 steps : Current avg of 10 episode's step = 2.1
# 2 Episode : Finished after 11 steps : Current avg of 10 episode's step = 3.2
# 3 Episode : Finished after 11 steps : Current avg of 10 episode's step = 4.3
# 4 Episode : Finished after 10 steps : Current avg of 10 episode's step = 5.3
# 5 Episode : Finished after 9 steps : Current avg of 10 episode's step = 6.2
# 6 Episode : Finished after 11 steps : Current avg of 10 episode's step = 7.3
# 7 Episode : Finished after 10 steps : Current avg of 10 episode's step = 8.3
# 8 Episode : Finished after 8 steps : Current avg of 10 episode's step = 9.1
# 9 Episode : Finished after 9 steps : Current avg of 10 episode's step = 10.0
# 10 Episode : Finished after 11 steps : Current avg of 10 episode's step = 10.2
# 11 Episode : Finished after 10 steps : Current avg of 10 episode's step = 10.0
# 12 Episode : Finished after 10 steps : Current avg of 10 episode's step = 9.9
# 13 Episode : Finished after 11 steps : Current avg of 10 episode's step = 9.9
# 14 Episode : Finished after 9 steps : Current avg of 10 episode's step = 9.8
# 15 Episode : Finished after 9 steps : Current avg of 10 episode's step = 9.8
# 16 Episode : Finished after 13 steps : Current avg of 10 episode's step = 10.0
# 17 Episode : Finished after 12 steps : Current avg of 10 episode's step = 10.2
# 18 Episode : Finished after 12 steps : Current avg of 10 episode's step = 10.6
# 19 Episode : Finished after 37 steps : Current avg of 10 episode's step = 13.4
# 20 Episode : Finished after 17 steps : Current avg of 10 episode's step = 14.0
# 21 Episode : Finished after 37 steps : Current avg of 10 episode's step = 16.7
# 22 Episode : Finished after 24 steps : Current avg of 10 episode's step = 18.1
# 23 Episode : Finished after 22 steps : Current avg of 10 episode's step = 19.2
# 24 Episode : Finished after 21 steps : Current avg of 10 episode's step = 20.4
# 25 Episode : Finished after 29 steps : Current avg of 10 episode's step = 22.4
# 26 Episode : Finished after 23 steps : Current avg of 10 episode's step = 23.4
# 27 Episode : Finished after 24 steps : Current avg of 10 episode's step = 24.6
# 28 Episode : Finished after 24 steps : Current avg of 10 episode's step = 25.8
# 29 Episode : Finished after 17 steps : Current avg of 10 episode's step = 23.8
# 30 Episode : Finished after 33 steps : Current avg of 10 episode's step = 25.4
# 31 Episode : Finished after 23 steps : Current avg of 10 episode's step = 24.0
# 32 Episode : Finished after 34 steps : Current avg of 10 episode's step = 25.0
# 33 Episode : Finished after 41 steps : Current avg of 10 episode's step = 26.9
# 34 Episode : Finished after 32 steps : Current avg of 10 episode's step = 28.0
# 35 Episode : Finished after 42 steps : Current avg of 10 episode's step = 29.3
# 36 Episode : Finished after 27 steps : Current avg of 10 episode's step = 29.7
# 37 Episode : Finished after 60 steps : Current avg of 10 episode's step = 33.3
# 38 Episode : Finished after 72 steps : Current avg of 10 episode's step = 38.1
# 39 Episode : Finished after 53 steps : Current avg of 10 episode's step = 41.7
# 40 Episode : Finished after 61 steps : Current avg of 10 episode's step = 44.5
# 41 Episode : Finished after 81 steps : Current avg of 10 episode's step = 50.3
# 42 Episode : Finished after 38 steps : Current avg of 10 episode's step = 50.7
# 43 Episode : Finished after 59 steps : Current avg of 10 episode's step = 52.5
# 44 Episode : Finished after 43 steps : Current avg of 10 episode's step = 53.6
# 45 Episode : Finished after 54 steps : Current avg of 10 episode's step = 54.8
# 46 Episode : Finished after 40 steps : Current avg of 10 episode's step = 56.1
# 47 Episode : Finished after 57 steps : Current avg of 10 episode's step = 55.8
# 48 Episode : Finished after 43 steps : Current avg of 10 episode's step = 52.9
# 49 Episode : Finished after 71 steps : Current avg of 10 episode's step = 54.7
# 50 Episode : Finished after 86 steps : Current avg of 10 episode's step = 57.2
# 51 Episode : Finished after 84 steps : Current avg of 10 episode's step = 57.5
# 52 Episode : Finished after 71 steps : Current avg of 10 episode's step = 60.8
# 53 Episode : Finished after 87 steps : Current avg of 10 episode's step = 63.6
# 54 Episode : Finished after 55 steps : Current avg of 10 episode's step = 64.8
# 55 Episode : Finished after 105 steps : Current avg of 10 episode's step = 69.9
# 56 Episode : Finished after 70 steps : Current avg of 10 episode's step = 72.9
# 57 Episode : Finished after 109 steps : Current avg of 10 episode's step = 78.1
# 58 Episode : Finished after 107 steps : Current avg of 10 episode's step = 84.5
# 59 Episode : Finished after 89 steps : Current avg of 10 episode's step = 86.3
# 60 Episode : Finished after 91 steps : Current avg of 10 episode's step = 86.8
# 61 Episode : Finished after 97 steps : Current avg of 10 episode's step = 88.1
# 62 Episode : Finished after 178 steps : Current avg of 10 episode's step = 98.8
# 63 Episode : Finished after 140 steps : Current avg of 10 episode's step = 104.1
# 64 Episode : Finished after 174 steps : Current avg of 10 episode's step = 116.0
# 65 Episode : Finished after 200 steps : Current avg of 10 episode's step = 125.5
# 66 Episode : Finished after 200 steps : Current avg of 10 episode's step = 138.5
# 67 Episode : Finished after 194 steps : Current avg of 10 episode's step = 147.0
# 68 Episode : Finished after 114 steps : Current avg of 10 episode's step = 147.7
# 69 Episode : Finished after 200 steps : Current avg of 10 episode's step = 158.8
# 70 Episode : Finished after 200 steps : Current avg of 10 episode's step = 169.7
# 71 Episode : Finished after 200 steps : Current avg of 10 episode's step = 180.0
# 72 Episode : Finished after 200 steps : Current avg of 10 episode's step = 182.2
# 73 Episode : Finished after 200 steps : Current avg of 10 episode's step = 188.2
# 74 Episode : Finished after 200 steps : Current avg of 10 episode's step = 190.8
# 75 Episode : Finished after 200 steps : Current avg of 10 episode's step = 190.8
# 76 Episode : Finished after 200 steps : Current avg of 10 episode's step = 190.8
# 77 Episode : Finished after 200 steps : Current avg of 10 episode's step = 191.4
# 78 Episode : Finished after 190 steps : Current avg of 10 episode's step = 199.0
# 79 Episode : Finished after 200 steps : Current avg of 10 episode's step = 199.0
# 80 Episode : Finished after 200 steps : Current avg of 10 episode's step = 199.0
# 81 Episode : Finished after 186 steps : Current avg of 10 episode's step = 197.6
# 82 Episode : Finished after 200 steps : Current avg of 10 episode's step = 197.6
# 83 Episode : Finished after 200 steps : Current avg of 10 episode's step = 197.6
# 84 Episode : Finished after 200 steps : Current avg of 10 episode's step = 197.6
# 85 Episode : Finished after 200 steps : Current avg of 10 episode's step = 197.6
# 86 Episode : Finished after 200 steps : Current avg of 10 episode's step = 197.6
# 87 Episode : Finished after 200 steps : Current avg of 10 episode's step = 197.6
# 88 Episode : Finished after 200 steps : Current avg of 10 episode's step = 198.6
# 89 Episode : Finished after 200 steps : Current avg of 10 episode's step = 198.6
# 90 Episode : Finished after 200 steps : Current avg of 10 episode's step = 198.6
# 91 Episode : Finished after 200 steps : Current avg of 10 episode's step = 200.0
# 10 episode success
