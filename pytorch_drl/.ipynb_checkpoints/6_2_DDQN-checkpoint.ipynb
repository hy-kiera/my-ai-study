# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import gym

# %%
from JSAnimation.IPython_display import display_animation
from matplotlib import animation
from IPython.display import display

def display_frames_as_gif(frames):
    '''Displays a list of frames as a gif, with controls'''
    plt.figure(figsize=(frames[0].shape[1]/72.0, frames[0].shape[0]/72.0), dpi=72)
    patch = plt.imshow(frames[0])
    plt.axis('off')
    
    def animate(i):
        patch.set_data(frames[i])
        
    anim = animation.FuncAnimation(plt.gcf(), animate, frames=len(frames), interval=50)
    
    anim.save('movie_cartpole_DQN.mp4')
    display(display_animation(anim, default_mode='loop'))

# %%
# using namedtuple
from collections import namedtuple

# ex
# Tr = namedtuple('tr', ('name_a', 'value_b'))
# Tr_object = Tr('nameA', 100)

# print(Tr_object)
# print(Tr_object.value_b)

Transition = namedtuple('Transition', ('state', 'action', 'next_state', 'reward'))

# %%
ENV = 'CartPole-v0'
GAMMA = 0.99 # 시간할인율
MAX_STEPS = 200 # 1에피소드 당 최대 단계 수
NUM_EPISODES = 500 # 최대 에피소드 수

# %%
# experience replay
class ReplayMemory:
    def __init__(self, CAPACITY):
        self.capacity = CAPACITY
        self.memory = []
        self.index = 0
        
    def push(self, state, action, state_next, reward):
        '''transition = (state, action, state_next, reward)을 메모리에 저장'''
        if len(self.memory) < self.capacity:
            self.memory.append(None)
            
        self.memory[self.index] = Transition(state, action, state_next, reward)
        self.index = (self.index + 1) % self.capacity
        
    def sample(self, batch_size):
        '''batch_size 개수만큼 무작위로 저장된 transition을 추출'''
        return random.sample(self.memory, batch_size)
    
    def __len__(self):
        '''len 함수로 현재 저장된 transition 개수를 반환'''
        return len(self.memory)

# %%
# NN
import torch.nn as nn
import torch.nn.functional as F

class Net(nn.Module):
    def __init__(self, n_in, n_mid, n_out):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(n_in, n_mid)
        self.fc2 = nn.Linear(n_mid, n_mid)
        self.fc3 = nn.Linear(n_mid, n_out)
        
    def forward(self, x):
        h1 = F.relu(self.fc1(x))
        h2 = F.relu(self.fc2(h1))
        output = self.fc3(h2)
        return output

# %%
import random
import torch
from torch import nn
from torch import optim
import torch.nn.functional as F

BATCH_SIZE = 32
CAPACITY = 10000

class Brain:
    def __init__(self, num_states, num_actions):
        self.num_actions = num_actions # 행동 가짓수(2)
        
        # transition을 기억하기 위한 메모리 객체 생성
        self.memory = ReplayMemory(CAPACITY)
        
        # nn
        n_in, n_mid, n_out = num_states, 32, num_actions
        self.main_q_network = Net(n_in, n_mid, n_out)
        self.target_q_network = Net(n_in, n_mid, n_out)
        print(self.main_q_network)
        
        self.optimizer = optim.Adam(self.main_q_network.parameters(), lr=0.0001)
        
    def replay(self):
        '''Experience Replay로 신경망의 결합 가중치 학습'''

        # 1. 저장된 transition의 수를 확인
        if len(self.memory)  < BATCH_SIZE:
            return
        
        # 2. 미니배치 생성
        self.batch, self.state_batch, self.action_batch, self.reward_batch, self.non_final_next_states = self.make_minibatch()
        
        # 3. 정답신호로 사용할 Q(s_t, a_t)를 계산
        self.expected_state_action_values = self.get_expected_state_action_values()
        
        # 4. 결합 가중치 수정
        self.update_main_q_network()

    def decide_action(self, state, episode):
        '''현재 상태에 따라 행동을 결정한다'''
        # ε-greedy 알고리즘에서 서서히 최적행동의 비중을 늘린다
        epsilon = 0.5 * (1 / (episode + 1))

        if epsilon <= np.random.uniform(0, 1):
            self.main_q_network.eval()  # 신경망을 추론 모드로 전환
            with torch.no_grad():
                action = self.main_q_network(state).max(1)[1].view(1, 1)
            # 신경망 출력의 최댓값에 대한 인덱스 = max(1)[1]
            # .view(1,1)은 [torch.LongTensor of size 1] 을 size 1*1로 변환하는 역할을 한다

        else:
            # 행동을 무작위로 반환(0 혹은 1)
            action = torch.LongTensor(
                [[random.randrange(self.num_actions)]])  # 행동을 무작위로 반환(0 혹은 1)
            # action은 [torch.LongTensor of size 1*1] 형태가 된다

        return action
    
    def make_minibatch(self):
        # 메모리 객체에서 미니배치 추출
        transitions = self.memory.sample(BATCH_SIZE)
        
        batch = Transition(*zip(*transitions))
        
        state_batch = torch.cat(batch.state)
        action_batch = torch.cat(batch.action)
        reward_batch = torch.cat(batch.reward)
        non_final_next_states = torch.cat([s for s in batch.next_state if s is not None])
        
        return batch, state_batch, action_batch, reward_batch, non_final_next_states
    
    def get_expected_state_action_values(self):
        self.main_q_network.eval()
        self. target_q_network.eval()
        
        # 신경망으로 Q(s_t,a_t)를 계산
        # self.model(state_batch)은 왼쪽, 오른쪽에 대한 Q값을 출력하며 [torch.FloatTensor of size BATCH_SIZEx2] 형태
        # 여기서부터 실행한 행동 a_t에 대한 Q값을 계산하므로 action_batch에서 취한 행동 a_t가 왼쪽이냐 오른쪽이냐에 대한 인덱스를 구하고,
        # 이에 대한 Q값을 gather 메서드로 모아온다
        self.state_action_values = self.main_q_network(self.state_batch).gather(1, self.action_batch)
        
        non_final_mask = torch.ByteTensor(tuple(map(lambda s: s is not None, self.batch.next_state)))
        
        next_state_values = torch.zeros(BATCH_SIZE)
        a_m = torch.zeros(BATCH_SIZE).type(torch.LongTensor)
        
        a_m[non_final_mask] = self.main_q_network(self.non_final_next_states).detach().max(1)[1]
        
        a_m_non_final_states = a_m[non_final_mask].view(-1, 1)
        
        next_state_values[non_final_mask] = self.target_q_network(self.non_final_next_states).gather(1, a_m_non_final_states).detach().squeeze()
        
        expected_state_action_values = self.reward_batch + GAMMA * next_state_values
        
        return expected_state_action_values
    
    
    def update_main_q_network(self):
        self.main_q_network.train()
        
        # smooth_l1_loss : Huber function
        loss = F.smooth_l1_loss(self.state_action_values, self.expected_state_action_values.unsqueeze(1))
        
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()
        
    def update_target_q_network(self):
        '''Target Q-Network을 Main Q-Network와 맞춤'''
        self.target_q_network.load_state_dict(self.main_q_network.state_dict())

# %%
class Agent:
    def __init__(self, num_states, num_actions):
        self.brain = Brain(num_states, num_actions)
        
    def update_q_function(self):
        self.brain.replay()
    
    def get_action(self, state, episode):
        action = self.brain.decide_action(state, episode)
        return action

    def memorize(self, state, action, state_next, reward):
        self.brain.memory.push(state, action, state_next, reward)
        
    def update_target_q_function(self):
        self.brain.update_target_q_network()

# %%
class Environment:
    def __init__(self):
        self.env = gym.make(ENV)
        num_states = self.env.observation_space.shape[0]
        num_actions = self.env.action_space.n
        self.agent = Agent(num_states, num_actions)
        
    def run(self):
        episode_10_list = np.zeros(10)
        complete_episodes = 0
        episode_final = False
        frames = []
        
        for episode in range(NUM_EPISODES):
            observation = self.env.reset()
            
            state = observation
            state = torch.from_numpy(state).type(torch.FloatTensor)
            state = torch.unsqueeze(state, 0)
            
            for step in range(MAX_STEPS):
#                 if episode_final is True:
#                     frames.append(self.env.render(mode='rgb_array'))
                action = self.agent.get_action(state, episode)
                
                observation_next, _, done, _ = self.env.step(action.item())
                
                if done:
                    state_next = None
                    episode_10_list = np.hstack((episode_10_list[1:], step + 1))
                    
                    if step < 195:
                        reward = torch.FloatTensor([-1.0])
                        complete_episodes = 0
                    else:
                        reward = torch.FloatTensor([1.0])
                        complete_episodes = complete_episodes + 1
                        
                else:
                    reward = torch.FloatTensor([0.0])
                    state_next = observation_next
                    state_next = torch.from_numpy(state_next).type(torch.FloatTensor)
                    state_next = torch.unsqueeze(state_next, 0)
                    
                self.agent.memorize(state, action, state_next, reward)
                
                self.agent.update_q_function()
                
                state = state_next
                
                if done:
                    print('%d Episode : Finished after %d steps : Current avg of 10 episode\'s step = %.1lf' % (episode, step + 1, episode_10_list.mean()))
                    if (episode % 2 == 0):
                        self.agent.update_target_q_function()
                    break
                
                if episode_final is True:
#                     display_frames_as_gif(frames)
                    break
                
                if complete_episodes >= 10:
                    print("10 episode success")
                    episode_final = True

# %%
cartpole_env = Environment()
cartpole_env.run()
# Out:
# Net(
#   (fc1): Linear(in_features=4, out_features=32, bias=True)
#   (fc2): Linear(in_features=32, out_features=32, bias=True)
#   (fc3): Linear(in_features=32, out_features=2, bias=True)
# )
# 0 Episode : Finished after 15 steps : Current avg of 10 episode's step = 1.5
# 1 Episode : Finished after 11 steps : Current avg of 10 episode's step = 2.6
# 2 Episode : Finished after 8 steps : Current avg of 10 episode's step = 3.4
# 3 Episode : Finished after 10 steps : Current avg of 10 episode's step = 4.4
# 4 Episode : Finished after 9 steps : Current avg of 10 episode's step = 5.3
# 5 Episode : Finished after 11 steps : Current avg of 10 episode's step = 6.4
# 6 Episode : Finished after 9 steps : Current avg of 10 episode's step = 7.3
# 7 Episode : Finished after 8 steps : Current avg of 10 episode's step = 8.1
# 8 Episode : Finished after 10 steps : Current avg of 10 episode's step = 9.1
# 9 Episode : Finished after 9 steps : Current avg of 10 episode's step = 10.0
# 10 Episode : Finished after 9 steps : Current avg of 10 episode's step = 9.4
# 11 Episode : Finished after 9 steps : Current avg of 10 episode's step = 9.2
# 12 Episode : Finished after 10 steps : Current avg of 10 episode's step = 9.4
# 13 Episode : Finished after 10 steps : Current avg of 10 episode's step = 9.4
# 14 Episode : Finished after 10 steps : Current avg of 10 episode's step = 9.5
# 15 Episode : Finished after 9 steps : Current avg of 10 episode's step = 9.3
# 16 Episode : Finished after 10 steps : Current avg of 10 episode's step = 9.4
# 17 Episode : Finished after 9 steps : Current avg of 10 episode's step = 9.5
# 18 Episode : Finished after 29 steps : Current avg of 10 episode's step = 11.4
# 19 Episode : Finished after 10 steps : Current avg of 10 episode's step = 11.5
# 20 Episode : Finished after 10 steps : Current avg of 10 episode's step = 11.6
# 21 Episode : Finished after 9 steps : Current avg of 10 episode's step = 11.6
# 22 Episode : Finished after 10 steps : Current avg of 10 episode's step = 11.6
# 23 Episode : Finished after 9 steps : Current avg of 10 episode's step = 11.5
# 24 Episode : Finished after 12 steps : Current avg of 10 episode's step = 11.7
# 25 Episode : Finished after 8 steps : Current avg of 10 episode's step = 11.6
# 26 Episode : Finished after 10 steps : Current avg of 10 episode's step = 11.6
# 27 Episode : Finished after 10 steps : Current avg of 10 episode's step = 11.7
# 28 Episode : Finished after 11 steps : Current avg of 10 episode's step = 9.9
# 29 Episode : Finished after 9 steps : Current avg of 10 episode's step = 9.8
# 30 Episode : Finished after 10 steps : Current avg of 10 episode's step = 9.8
# 31 Episode : Finished after 9 steps : Current avg of 10 episode's step = 9.8
# 32 Episode : Finished after 51 steps : Current avg of 10 episode's step = 13.9
# 33 Episode : Finished after 25 steps : Current avg of 10 episode's step = 15.5
# 34 Episode : Finished after 24 steps : Current avg of 10 episode's step = 16.7
# 35 Episode : Finished after 30 steps : Current avg of 10 episode's step = 18.9
# 36 Episode : Finished after 22 steps : Current avg of 10 episode's step = 20.1
# 37 Episode : Finished after 23 steps : Current avg of 10 episode's step = 21.4
# 38 Episode : Finished after 16 steps : Current avg of 10 episode's step = 21.9
# 39 Episode : Finished after 22 steps : Current avg of 10 episode's step = 23.2
# 40 Episode : Finished after 19 steps : Current avg of 10 episode's step = 24.1
# 41 Episode : Finished after 23 steps : Current avg of 10 episode's step = 25.5
# 42 Episode : Finished after 17 steps : Current avg of 10 episode's step = 22.1
# 43 Episode : Finished after 22 steps : Current avg of 10 episode's step = 21.8
# 44 Episode : Finished after 21 steps : Current avg of 10 episode's step = 21.5
# 45 Episode : Finished after 22 steps : Current avg of 10 episode's step = 20.7
# 46 Episode : Finished after 18 steps : Current avg of 10 episode's step = 20.3
# 47 Episode : Finished after 26 steps : Current avg of 10 episode's step = 20.6
# 48 Episode : Finished after 28 steps : Current avg of 10 episode's step = 21.8
# 49 Episode : Finished after 20 steps : Current avg of 10 episode's step = 21.6
# 50 Episode : Finished after 28 steps : Current avg of 10 episode's step = 22.5
# 51 Episode : Finished after 28 steps : Current avg of 10 episode's step = 23.0
# 52 Episode : Finished after 17 steps : Current avg of 10 episode's step = 23.0
# 53 Episode : Finished after 16 steps : Current avg of 10 episode's step = 22.4
# 54 Episode : Finished after 25 steps : Current avg of 10 episode's step = 22.8
# 55 Episode : Finished after 18 steps : Current avg of 10 episode's step = 22.4
# 56 Episode : Finished after 30 steps : Current avg of 10 episode's step = 23.6
# 57 Episode : Finished after 27 steps : Current avg of 10 episode's step = 23.7
# 58 Episode : Finished after 22 steps : Current avg of 10 episode's step = 23.1
# 59 Episode : Finished after 23 steps : Current avg of 10 episode's step = 23.4
# 60 Episode : Finished after 22 steps : Current avg of 10 episode's step = 22.8
# 61 Episode : Finished after 25 steps : Current avg of 10 episode's step = 22.5
# 62 Episode : Finished after 61 steps : Current avg of 10 episode's step = 26.9
# 63 Episode : Finished after 45 steps : Current avg of 10 episode's step = 29.8
# 64 Episode : Finished after 49 steps : Current avg of 10 episode's step = 32.2
# 65 Episode : Finished after 76 steps : Current avg of 10 episode's step = 38.0
# 66 Episode : Finished after 55 steps : Current avg of 10 episode's step = 40.5
# 67 Episode : Finished after 60 steps : Current avg of 10 episode's step = 43.8
# 68 Episode : Finished after 103 steps : Current avg of 10 episode's step = 51.9
# 69 Episode : Finished after 40 steps : Current avg of 10 episode's step = 53.6
# 70 Episode : Finished after 85 steps : Current avg of 10 episode's step = 59.9
# 71 Episode : Finished after 75 steps : Current avg of 10 episode's step = 64.9
# 72 Episode : Finished after 107 steps : Current avg of 10 episode's step = 69.5
# 73 Episode : Finished after 73 steps : Current avg of 10 episode's step = 72.3
# 74 Episode : Finished after 75 steps : Current avg of 10 episode's step = 74.9
# 75 Episode : Finished after 94 steps : Current avg of 10 episode's step = 76.7
# 76 Episode : Finished after 126 steps : Current avg of 10 episode's step = 83.8
# 77 Episode : Finished after 125 steps : Current avg of 10 episode's step = 90.3
# 78 Episode : Finished after 117 steps : Current avg of 10 episode's step = 91.7
# 79 Episode : Finished after 56 steps : Current avg of 10 episode's step = 93.3
# 80 Episode : Finished after 135 steps : Current avg of 10 episode's step = 98.3
# 81 Episode : Finished after 84 steps : Current avg of 10 episode's step = 99.2
# 82 Episode : Finished after 99 steps : Current avg of 10 episode's step = 98.4
# 83 Episode : Finished after 108 steps : Current avg of 10 episode's step = 101.9
# 84 Episode : Finished after 86 steps : Current avg of 10 episode's step = 103.0
# 85 Episode : Finished after 111 steps : Current avg of 10 episode's step = 104.7
# 86 Episode : Finished after 194 steps : Current avg of 10 episode's step = 111.5
# 87 Episode : Finished after 182 steps : Current avg of 10 episode's step = 117.2
# 88 Episode : Finished after 149 steps : Current avg of 10 episode's step = 120.4
# 89 Episode : Finished after 177 steps : Current avg of 10 episode's step = 132.5
# 90 Episode : Finished after 200 steps : Current avg of 10 episode's step = 139.0
# 91 Episode : Finished after 110 steps : Current avg of 10 episode's step = 141.6
# 92 Episode : Finished after 200 steps : Current avg of 10 episode's step = 151.7
# 93 Episode : Finished after 134 steps : Current avg of 10 episode's step = 154.3
# 94 Episode : Finished after 142 steps : Current avg of 10 episode's step = 159.9
# 95 Episode : Finished after 153 steps : Current avg of 10 episode's step = 164.1
# 96 Episode : Finished after 83 steps : Current avg of 10 episode's step = 153.0
# 97 Episode : Finished after 200 steps : Current avg of 10 episode's step = 154.8
# 98 Episode : Finished after 200 steps : Current avg of 10 episode's step = 159.9
# 99 Episode : Finished after 125 steps : Current avg of 10 episode's step = 154.7
# 100 Episode : Finished after 132 steps : Current avg of 10 episode's step = 147.9
# 101 Episode : Finished after 178 steps : Current avg of 10 episode's step = 154.7
# 102 Episode : Finished after 200 steps : Current avg of 10 episode's step = 154.7
# 103 Episode : Finished after 120 steps : Current avg of 10 episode's step = 153.3
# 104 Episode : Finished after 200 steps : Current avg of 10 episode's step = 159.1
# 105 Episode : Finished after 200 steps : Current avg of 10 episode's step = 163.8
# 106 Episode : Finished after 200 steps : Current avg of 10 episode's step = 175.5
# 107 Episode : Finished after 179 steps : Current avg of 10 episode's step = 173.4
# 108 Episode : Finished after 120 steps : Current avg of 10 episode's step = 165.4
# 109 Episode : Finished after 114 steps : Current avg of 10 episode's step = 164.3
# 110 Episode : Finished after 158 steps : Current avg of 10 episode's step = 166.9
# 111 Episode : Finished after 142 steps : Current avg of 10 episode's step = 163.3
# 112 Episode : Finished after 200 steps : Current avg of 10 episode's step = 163.3
# 113 Episode : Finished after 200 steps : Current avg of 10 episode's step = 171.3
# 114 Episode : Finished after 200 steps : Current avg of 10 episode's step = 171.3
# 115 Episode : Finished after 200 steps : Current avg of 10 episode's step = 171.3
# 116 Episode : Finished after 200 steps : Current avg of 10 episode's step = 171.3
# 117 Episode : Finished after 200 steps : Current avg of 10 episode's step = 173.4
# 118 Episode : Finished after 200 steps : Current avg of 10 episode's step = 181.4
# 119 Episode : Finished after 200 steps : Current avg of 10 episode's step = 190.0
# 120 Episode : Finished after 200 steps : Current avg of 10 episode's step = 194.2
# 121 Episode : Finished after 200 steps : Current avg of 10 episode's step = 200.0
# 10 episode success
