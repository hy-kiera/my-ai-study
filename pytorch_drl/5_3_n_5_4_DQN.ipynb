# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import gym

# %%
from JSAnimation.IPython_display import display_animation
from matplotlib import animation
from IPython.display import display

def display_frames_as_gif(frames):
    '''Displays a list of frames as a gif, with controls'''
    plt.figure(figsize=(frames[0].shape[1]/72.0, frames[0].shape[0]/72.0), dpi=72)
    patch = plt.imshow(frames[0])
    plt.axis('off')
    
    def animate(i):
        patch.set_data(frames[i])
        
    anim = animation.FuncAnimation(plt.gcf(), animate, frames=len(frames), interval=50)
    
    anim.save('movie_cartpole_DQN.mp4')
    display(display_animation(anim, default_mode='loop'))

# %%
# using namedtuple
from collections import namedtuple

# ex
# Tr = namedtuple('tr', ('name_a', 'value_b'))
# Tr_object = Tr('nameA', 100)

# print(Tr_object)
# print(Tr_object.value_b)

Transition = namedtuple('Transition', ('state', 'action', 'next_state', 'reward'))

# %%
ENV = 'CartPole-v0'
GAMMA = 0.99 # 시간할인율
MAX_STEPS = 200 # 1에피소드 당 최대 단계 수
NUM_EPISODES = 500 # 최대 에피소드 수

# %%
# experience replay
class ReplayMemory:
    def __init__(self, CAPACITY):
        self.capacity = CAPACITY
        self.memory = []
        self.index = 0
        
    def push(self, state, action, state_next, reward):
        '''transition = (state, action, state_next, reward)을 메모리에 저장'''
        if len(self.memory) < self.capacity:
            self.memory.append(None)
            
        self.memory[self.index] = Transition(state, action, state_next, reward)
        self.index = (self.index + 1) % self.capacity
        
    def sample(self, batch_size):
        '''batch_size 개수만큼 무작위로 저장된 transition을 추출'''
        return random.sample(self.memory, batch_size)
    
    def __len__(self):
        '''len 함수로 현재 저장된 transition 개수를 반환'''
        return len(self.memory)

# %%
import random
import torch
from torch import nn
from torch import optim
import torch.nn.functional as F

BATCH_SIZE = 32
CAPACITY = 10000

class Brain:
    def __init__(self, num_states, num_actions):
        self.num_actions = num_actions
        
        self.memory = ReplayMemory(CAPACITY)
        
        self.model = nn.Sequential()
        self.model.add_module('fc1', nn.Linear(num_states, 32))
        self.model.add_module('relu1', nn.ReLU())
        self.model.add_module('fc2', nn.Linear(32, 32))
        self.model.add_module('relu2', nn.ReLU())
        self.model.add_module('fc3', nn.Linear(32, num_actions))
        
        print(self.model)
        
        self.optimizer = optim.Adam(self.model.parameters(), lr=0.0001)
        
    def replay(self):
        '''Experience Replay로 신경망의 결합 가중치 학습'''

        # -----------------------------------------
        # 1. 저장된 transition 수 확인
        # -----------------------------------------
        # 1.1 저장된 transition의 수가 미니배치 크기보다 작으면 아무 것도 하지 않음
        if len(self.memory) < BATCH_SIZE:
            return

        # -----------------------------------------
        # 2. 미니배치 생성
        # -----------------------------------------
        # 2.1 메모리 객체에서 미니배치를 추출
        transitions = self.memory.sample(BATCH_SIZE)

        # 2.2 각 변수를 미니배치에 맞는 형태로 변형
        # transitions는 각 단계 별로 (state, action, state_next, reward) 형태로 BATCH_SIZE 갯수만큼 저장됨
        # 다시 말해, (state, action, state_next, reward) * BATCH_SIZE 형태가 된다
        # 이것을 미니배치로 만들기 위해
        # (state*BATCH_SIZE, action*BATCH_SIZE, state_next*BATCH_SIZE, reward*BATCH_SIZE) 형태로 변환한다
        batch = Transition(*zip(*transitions))

        # 2.3 각 변수의 요소를 미니배치에 맞게 변형하고, 신경망으로 다룰 수 있도록 Variable로 만든다
        # state를 예로 들면, [torch.FloatTensor of size 1*4] 형태의 요소가 BATCH_SIZE 갯수만큼 있는 형태이다
        # 이를 torch.FloatTensor of size BATCH_SIZE*4 형태로 변형한다
        # 상태, 행동, 보상, non_final 상태로 된 미니배치를 나타내는 Variable을 생성
        # cat은 Concatenates(연접)을 의미한다
        state_batch = torch.cat(batch.state)
        action_batch = torch.cat(batch.action)
        reward_batch = torch.cat(batch.reward)
        non_final_next_states = torch.cat([s for s in batch.next_state
                                           if s is not None])

        # -----------------------------------------
        # 3. 정답신호로 사용할 Q(s_t, a_t)를 계산
        # -----------------------------------------
        # 3.1 신경망을 추론 모드로 전환
        self.model.eval()

        # 3.2 신경망으로 Q(s_t, a_t)를 계산
        # self.model(state_batch)은 왼쪽, 오른쪽에 대한 Q값을 출력하며
        # [torch.FloatTensor of size BATCH_SIZEx2] 형태이다
        # 여기서부터는 실행한 행동 a_t에 대한 Q값을 계산하므로 action_batch에서 취한 행동 a_t가 
        # 왼쪽이냐 오른쪽이냐에 대한 인덱스를 구하고, 이에 대한 Q값을 gather 메서드로 모아온다
        state_action_values = self.model(state_batch).gather(1, action_batch)

        # 3.3 max{Q(s_t+1, a)}값을 계산한다 이때 다음 상태가 존재하는지에 주의해야 한다

        # cartpole이 done 상태가 아니고, next_state가 존재하는지 확인하는 인덱스 마스크를 만듬
        non_final_mask = torch.ByteTensor(tuple(map(lambda s: s is not None,
                                                    batch.next_state)))
        # 먼저 전체를 0으로 초기화
        next_state_values = torch.zeros(BATCH_SIZE)

        # 다음 상태가 있는 인덱스에 대한 최대 Q값을 구한다
        # 출력에 접근하여 열방향 최대값(max(1))이 되는 [값, 인덱스]를 구한다
        # 그리고 이 Q값(인덱스=0)을 출력한 다음
        # detach 메서드로 이 값을 꺼내온다
        next_state_values[non_final_mask] = self.model(
            non_final_next_states).max(1)[0].detach()

        # 3.4 정답신호로 사용할 Q(s_t, a_t)값을 Q러닝 식으로 계산한다
        expected_state_action_values = reward_batch + GAMMA * next_state_values

        # -----------------------------------------
        # 4. 결합 가중치 수정
        # -----------------------------------------
        # 4.1 신경망을 학습 모드로 전환
        self.model.train()

        # 4.2 손실함수를 계산 (smooth_l1_loss는 Huber 함수)
        # expected_state_action_values은
        # size가 [minibatch]이므로 unsqueeze하여 [minibatch*1]로 만든다
        loss = F.smooth_l1_loss(state_action_values,
                                expected_state_action_values.unsqueeze(1))

        # 4.3 결합 가중치를 수정한다
        self.optimizer.zero_grad()  # 경사를 초기화
        loss.backward()  # 역전파 계산
        self.optimizer.step()  # 결합 가중치 수정

    def decide_action(self, state, episode):
        '''현재 상태에 따라 행동을 결정한다'''
        # ε-greedy 알고리즘에서 서서히 최적행동의 비중을 늘린다
        epsilon = 0.5 * (1 / (episode + 1))

        if epsilon <= np.random.uniform(0, 1):
            self.model.eval()  # 신경망을 추론 모드로 전환
            with torch.no_grad():
                action = self.model(state).max(1)[1].view(1, 1)
            # 신경망 출력의 최댓값에 대한 인덱스 = max(1)[1]
            # .view(1,1)은 [torch.LongTensor of size 1] 을 size 1*1로 변환하는 역할을 한다

        else:
            # 행동을 무작위로 반환(0 혹은 1)
            action = torch.LongTensor(
                [[random.randrange(self.num_actions)]])  # 행동을 무작위로 반환(0 혹은 1)
            # action은 [torch.LongTensor of size 1*1] 형태가 된다

        return action

# %%
class Agent:
    def __init__(self, num_states, num_actions):
        self.brain = Brain(num_states, num_actions)
        
    def update_q_function(self):
        self.brain.replay()
    
    def get_action(self, state, episode):
        action = self.brain.decide_action(state, episode)
        return action

    def memorize(self, state, action, state_next, reward):
        self.brain.memory.push(state, action, state_next, reward)

# %%
class Environment:
    def __init__(self):
        self.env = gym.make(ENV)
        num_states = self.env.observation_space.shape[0]
        num_actions = self.env.action_space.n
        self.agent = Agent(num_states, num_actions)
        
    def run(self):
        episode_10_list = np.zeros(10)
        complete_episodes = 0
        episode_final = False
        frames = []
        
        for episode in range(NUM_EPISODES):
            observation = self.env.reset()
            
            state = observation
            state = torch.from_numpy(state).type(torch.FloatTensor)
            state = torch.unsqueeze(state, 0)
            
            for step in range(MAX_STEPS):
#                 if episode_final is True:
#                     frames.append(self.env.render(mode='rgb_array'))
                action = self.agent.get_action(state, episode)
                
                observation_next, _, done, _ = self.env.step(action.item())
                
                if done:
                    state_next = None
                    episode_10_list = np.hstack((episode_10_list[1:], step + 1))
                    
                    if step < 195:
                        reward = torch.FloatTensor([-1.0])
                        complete_episodes = 0
                    else:
                        reward = torch.FloatTensor([1.0])
                        complete_episodes = complete_episodes + 1
                        
                else:
                    reward = torch.FloatTensor([0.0])
                    state_next = observation_next
                    state_next = torch.from_numpy(state_next).type(torch.FloatTensor)
                    state_next = torch.unsqueeze(state_next, 0)
                    
                self.agent.memorize(state, action, state_next, reward)
                
                self.agent.update_q_function()
                
                state = state_next
                
                if done:
                    print('%d Episode : Finished after %d steps : Current avg of 10 episode\' step = %.1lf' % (episode, step + 1, episode_10_list.mean()))
                    break
                
                if episode_final is True:
#                     display_frames_as_gif(frames)
                    break
                
                if complete_episodes >= 10:
                    print("10 episode success")
                    episode_final = True

# %%
cartpole_env = Environment()
cartpole_env.run()
# Out:
# Sequential(
#   (fc1): Linear(in_features=4, out_features=32, bias=True)
#   (relu1): ReLU()
#   (fc2): Linear(in_features=32, out_features=32, bias=True)
#   (relu2): ReLU()
#   (fc3): Linear(in_features=32, out_features=2, bias=True)
# )
# 0 Episode : Finished after 9 steps : Current avg of 10 episode' step = 0.9
# 1 Episode : Finished after 14 steps : Current avg of 10 episode' step = 2.3
# 2 Episode : Finished after 11 steps : Current avg of 10 episode' step = 3.4
# 3 Episode : Finished after 9 steps : Current avg of 10 episode' step = 4.3
# 4 Episode : Finished after 15 steps : Current avg of 10 episode' step = 5.8
# 5 Episode : Finished after 14 steps : Current avg of 10 episode' step = 7.2
# 6 Episode : Finished after 38 steps : Current avg of 10 episode' step = 11.0
# 7 Episode : Finished after 21 steps : Current avg of 10 episode' step = 13.1
# 8 Episode : Finished after 11 steps : Current avg of 10 episode' step = 14.2
# 9 Episode : Finished after 19 steps : Current avg of 10 episode' step = 16.1
# 10 Episode : Finished after 15 steps : Current avg of 10 episode' step = 16.7
# 11 Episode : Finished after 19 steps : Current avg of 10 episode' step = 17.2
# 12 Episode : Finished after 23 steps : Current avg of 10 episode' step = 18.4
# 13 Episode : Finished after 17 steps : Current avg of 10 episode' step = 19.2
# 14 Episode : Finished after 14 steps : Current avg of 10 episode' step = 19.1
# 15 Episode : Finished after 12 steps : Current avg of 10 episode' step = 18.9
# 16 Episode : Finished after 12 steps : Current avg of 10 episode' step = 16.3
# 17 Episode : Finished after 9 steps : Current avg of 10 episode' step = 15.1
# 18 Episode : Finished after 10 steps : Current avg of 10 episode' step = 15.0
# 19 Episode : Finished after 10 steps : Current avg of 10 episode' step = 14.1
# 20 Episode : Finished after 16 steps : Current avg of 10 episode' step = 14.2
# 21 Episode : Finished after 15 steps : Current avg of 10 episode' step = 13.8
# 22 Episode : Finished after 14 steps : Current avg of 10 episode' step = 12.9
# 23 Episode : Finished after 17 steps : Current avg of 10 episode' step = 12.9
# 24 Episode : Finished after 28 steps : Current avg of 10 episode' step = 14.3
# 25 Episode : Finished after 13 steps : Current avg of 10 episode' step = 14.4
# 26 Episode : Finished after 11 steps : Current avg of 10 episode' step = 14.3
# 27 Episode : Finished after 11 steps : Current avg of 10 episode' step = 14.5
# 28 Episode : Finished after 11 steps : Current avg of 10 episode' step = 14.6
# 29 Episode : Finished after 10 steps : Current avg of 10 episode' step = 14.6
# 30 Episode : Finished after 12 steps : Current avg of 10 episode' step = 14.2
# 31 Episode : Finished after 10 steps : Current avg of 10 episode' step = 13.7
# 32 Episode : Finished after 10 steps : Current avg of 10 episode' step = 13.3
# 33 Episode : Finished after 10 steps : Current avg of 10 episode' step = 12.6
# 34 Episode : Finished after 12 steps : Current avg of 10 episode' step = 11.0
# 35 Episode : Finished after 15 steps : Current avg of 10 episode' step = 11.2
# 36 Episode : Finished after 14 steps : Current avg of 10 episode' step = 11.5
# 37 Episode : Finished after 10 steps : Current avg of 10 episode' step = 11.4
# 38 Episode : Finished after 13 steps : Current avg of 10 episode' step = 11.6
# 39 Episode : Finished after 14 steps : Current avg of 10 episode' step = 12.0
# 40 Episode : Finished after 10 steps : Current avg of 10 episode' step = 11.8
# 41 Episode : Finished after 11 steps : Current avg of 10 episode' step = 11.9
# 42 Episode : Finished after 13 steps : Current avg of 10 episode' step = 12.2
# 43 Episode : Finished after 12 steps : Current avg of 10 episode' step = 12.4
# 44 Episode : Finished after 15 steps : Current avg of 10 episode' step = 12.7
# 45 Episode : Finished after 11 steps : Current avg of 10 episode' step = 12.3
# 46 Episode : Finished after 14 steps : Current avg of 10 episode' step = 12.3
# 47 Episode : Finished after 15 steps : Current avg of 10 episode' step = 12.8
# 48 Episode : Finished after 12 steps : Current avg of 10 episode' step = 12.7
# 49 Episode : Finished after 14 steps : Current avg of 10 episode' step = 12.7
# 50 Episode : Finished after 18 steps : Current avg of 10 episode' step = 13.5
# 51 Episode : Finished after 12 steps : Current avg of 10 episode' step = 13.6
# 52 Episode : Finished after 24 steps : Current avg of 10 episode' step = 14.7
# 53 Episode : Finished after 17 steps : Current avg of 10 episode' step = 15.2
# 54 Episode : Finished after 41 steps : Current avg of 10 episode' step = 17.8
# 55 Episode : Finished after 27 steps : Current avg of 10 episode' step = 19.4
# 56 Episode : Finished after 42 steps : Current avg of 10 episode' step = 22.2
# 57 Episode : Finished after 66 steps : Current avg of 10 episode' step = 27.3
# 58 Episode : Finished after 45 steps : Current avg of 10 episode' step = 30.6
# 59 Episode : Finished after 18 steps : Current avg of 10 episode' step = 31.0
# 60 Episode : Finished after 24 steps : Current avg of 10 episode' step = 31.6
# 61 Episode : Finished after 40 steps : Current avg of 10 episode' step = 34.4
# 62 Episode : Finished after 43 steps : Current avg of 10 episode' step = 36.3
# 63 Episode : Finished after 36 steps : Current avg of 10 episode' step = 38.2
# 64 Episode : Finished after 27 steps : Current avg of 10 episode' step = 36.8
# 65 Episode : Finished after 31 steps : Current avg of 10 episode' step = 37.2
# 66 Episode : Finished after 23 steps : Current avg of 10 episode' step = 35.3
# 67 Episode : Finished after 61 steps : Current avg of 10 episode' step = 34.8
# 68 Episode : Finished after 25 steps : Current avg of 10 episode' step = 32.8
# 69 Episode : Finished after 26 steps : Current avg of 10 episode' step = 33.6
# 70 Episode : Finished after 44 steps : Current avg of 10 episode' step = 35.6
# 71 Episode : Finished after 36 steps : Current avg of 10 episode' step = 35.2
# 72 Episode : Finished after 26 steps : Current avg of 10 episode' step = 33.5
# 73 Episode : Finished after 31 steps : Current avg of 10 episode' step = 33.0
# 74 Episode : Finished after 26 steps : Current avg of 10 episode' step = 32.9
# 75 Episode : Finished after 25 steps : Current avg of 10 episode' step = 32.3
# 76 Episode : Finished after 29 steps : Current avg of 10 episode' step = 32.9
# 77 Episode : Finished after 28 steps : Current avg of 10 episode' step = 29.6
# 78 Episode : Finished after 52 steps : Current avg of 10 episode' step = 32.3
# 79 Episode : Finished after 33 steps : Current avg of 10 episode' step = 33.0
# 80 Episode : Finished after 33 steps : Current avg of 10 episode' step = 31.9
# 81 Episode : Finished after 28 steps : Current avg of 10 episode' step = 31.1
# 82 Episode : Finished after 26 steps : Current avg of 10 episode' step = 31.1
# 83 Episode : Finished after 54 steps : Current avg of 10 episode' step = 33.4
# 84 Episode : Finished after 39 steps : Current avg of 10 episode' step = 34.7
# 85 Episode : Finished after 25 steps : Current avg of 10 episode' step = 34.7
# 86 Episode : Finished after 49 steps : Current avg of 10 episode' step = 36.7
# 87 Episode : Finished after 69 steps : Current avg of 10 episode' step = 40.8
# 88 Episode : Finished after 57 steps : Current avg of 10 episode' step = 41.3
# 89 Episode : Finished after 32 steps : Current avg of 10 episode' step = 41.2
# 90 Episode : Finished after 39 steps : Current avg of 10 episode' step = 41.8
# 91 Episode : Finished after 71 steps : Current avg of 10 episode' step = 46.1
# 92 Episode : Finished after 33 steps : Current avg of 10 episode' step = 46.8
# 93 Episode : Finished after 80 steps : Current avg of 10 episode' step = 49.4
# 94 Episode : Finished after 39 steps : Current avg of 10 episode' step = 49.4
# 95 Episode : Finished after 106 steps : Current avg of 10 episode' step = 57.5
# 96 Episode : Finished after 30 steps : Current avg of 10 episode' step = 55.6
# 97 Episode : Finished after 46 steps : Current avg of 10 episode' step = 53.3
# 98 Episode : Finished after 36 steps : Current avg of 10 episode' step = 51.2
# 99 Episode : Finished after 54 steps : Current avg of 10 episode' step = 53.4
# 100 Episode : Finished after 59 steps : Current avg of 10 episode' step = 55.4
# 101 Episode : Finished after 25 steps : Current avg of 10 episode' step = 50.8
# 102 Episode : Finished after 73 steps : Current avg of 10 episode' step = 54.8
# 103 Episode : Finished after 29 steps : Current avg of 10 episode' step = 49.7
# 104 Episode : Finished after 47 steps : Current avg of 10 episode' step = 50.5
# 105 Episode : Finished after 106 steps : Current avg of 10 episode' step = 50.5
# 106 Episode : Finished after 88 steps : Current avg of 10 episode' step = 56.3
# 107 Episode : Finished after 58 steps : Current avg of 10 episode' step = 57.5
# 108 Episode : Finished after 200 steps : Current avg of 10 episode' step = 73.9
# 109 Episode : Finished after 55 steps : Current avg of 10 episode' step = 74.0
# 110 Episode : Finished after 49 steps : Current avg of 10 episode' step = 73.0
# 111 Episode : Finished after 116 steps : Current avg of 10 episode' step = 82.1
# 112 Episode : Finished after 56 steps : Current avg of 10 episode' step = 80.4
# 113 Episode : Finished after 61 steps : Current avg of 10 episode' step = 83.6
# 114 Episode : Finished after 64 steps : Current avg of 10 episode' step = 85.3
# 115 Episode : Finished after 74 steps : Current avg of 10 episode' step = 82.1
# 116 Episode : Finished after 66 steps : Current avg of 10 episode' step = 79.9
# 117 Episode : Finished after 66 steps : Current avg of 10 episode' step = 80.7
# 118 Episode : Finished after 85 steps : Current avg of 10 episode' step = 69.2
# 119 Episode : Finished after 84 steps : Current avg of 10 episode' step = 72.1
# 120 Episode : Finished after 58 steps : Current avg of 10 episode' step = 73.0
# 121 Episode : Finished after 61 steps : Current avg of 10 episode' step = 67.5
# 122 Episode : Finished after 110 steps : Current avg of 10 episode' step = 72.9
# 123 Episode : Finished after 88 steps : Current avg of 10 episode' step = 75.6
# 124 Episode : Finished after 72 steps : Current avg of 10 episode' step = 76.4
# 125 Episode : Finished after 79 steps : Current avg of 10 episode' step = 76.9
# 126 Episode : Finished after 82 steps : Current avg of 10 episode' step = 78.5
# 127 Episode : Finished after 86 steps : Current avg of 10 episode' step = 80.5
# 128 Episode : Finished after 64 steps : Current avg of 10 episode' step = 78.4
# 129 Episode : Finished after 87 steps : Current avg of 10 episode' step = 78.7
# 130 Episode : Finished after 77 steps : Current avg of 10 episode' step = 80.6
# 131 Episode : Finished after 88 steps : Current avg of 10 episode' step = 83.3
# 132 Episode : Finished after 123 steps : Current avg of 10 episode' step = 84.6
# 133 Episode : Finished after 200 steps : Current avg of 10 episode' step = 95.8
# 134 Episode : Finished after 200 steps : Current avg of 10 episode' step = 108.6
# 135 Episode : Finished after 200 steps : Current avg of 10 episode' step = 120.7
# 136 Episode : Finished after 84 steps : Current avg of 10 episode' step = 120.9
# 137 Episode : Finished after 139 steps : Current avg of 10 episode' step = 126.2
# 138 Episode : Finished after 95 steps : Current avg of 10 episode' step = 129.3
# 139 Episode : Finished after 200 steps : Current avg of 10 episode' step = 140.6
# 140 Episode : Finished after 200 steps : Current avg of 10 episode' step = 152.9
# 141 Episode : Finished after 198 steps : Current avg of 10 episode' step = 163.9
# 142 Episode : Finished after 200 steps : Current avg of 10 episode' step = 171.6
# 143 Episode : Finished after 134 steps : Current avg of 10 episode' step = 165.0
# 144 Episode : Finished after 137 steps : Current avg of 10 episode' step = 158.7
# 145 Episode : Finished after 125 steps : Current avg of 10 episode' step = 151.2
# 146 Episode : Finished after 111 steps : Current avg of 10 episode' step = 153.9
# 147 Episode : Finished after 156 steps : Current avg of 10 episode' step = 155.6
# 148 Episode : Finished after 185 steps : Current avg of 10 episode' step = 164.6
# 149 Episode : Finished after 200 steps : Current avg of 10 episode' step = 164.6
# 150 Episode : Finished after 200 steps : Current avg of 10 episode' step = 164.6
# 151 Episode : Finished after 200 steps : Current avg of 10 episode' step = 164.8
# 152 Episode : Finished after 200 steps : Current avg of 10 episode' step = 164.8
# 153 Episode : Finished after 200 steps : Current avg of 10 episode' step = 171.4
# 154 Episode : Finished after 177 steps : Current avg of 10 episode' step = 175.4
# 155 Episode : Finished after 156 steps : Current avg of 10 episode' step = 178.5
# 156 Episode : Finished after 200 steps : Current avg of 10 episode' step = 187.4
# 157 Episode : Finished after 200 steps : Current avg of 10 episode' step = 191.8
# 158 Episode : Finished after 200 steps : Current avg of 10 episode' step = 193.3
# 159 Episode : Finished after 200 steps : Current avg of 10 episode' step = 193.3
# 160 Episode : Finished after 200 steps : Current avg of 10 episode' step = 193.3
# 161 Episode : Finished after 200 steps : Current avg of 10 episode' step = 193.3
# 162 Episode : Finished after 200 steps : Current avg of 10 episode' step = 193.3
# 163 Episode : Finished after 200 steps : Current avg of 10 episode' step = 193.3
# 164 Episode : Finished after 200 steps : Current avg of 10 episode' step = 195.6
# 165 Episode : Finished after 200 steps : Current avg of 10 episode' step = 200.0
# 10 episode success
